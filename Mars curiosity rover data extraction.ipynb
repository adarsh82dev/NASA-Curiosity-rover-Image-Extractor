# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from io import BytesIO

API_KEY = 'DEMO_KEY'
ROVER = 'curiosity'
DATE = '2020-01-01'

url = f'https://api.nasa.gov/mars-photos/api/v1/rovers/{ROVER}/photos'
params = {
    'earth_date': DATE,
    'api_key': API_KEY
}

response = requests.get(url, params=params)
data = response.json()

if data['photos']:
    print(f"Found {len(data['photos'])} photos on {DATE}.")
    first_photo = data['photos'][0]
    img_url = first_photo['img_src']
    print(f"Image URL: {img_url}")
# Out:
# Found 1099 photos on 2020-01-01.
# Image URL: https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/02632/opgs/edr/fcam/FLB_631151762EDR_F0781002FHAZ00206M_.JPG
